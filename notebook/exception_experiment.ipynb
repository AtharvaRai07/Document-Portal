# %%
print("all ok")
# Out:
# all ok

# %%
import sys
import traceback

# %%
from logger.custom_logger import CustomLogger

# %%
logger = CustomLogger().get_logger("exception_experiment")

# %%
class DocumentPortalException(Exception):
    """Custom exception for Document Portal errors."""
    def __init__(self, error_messasge:str, error_details:sys):
        _, _, exc_tb = error_details.exc_info()
        self.lineno = exc_tb.tb_lineno
        self.filename = exc_tb.tb_frame.f_code.co_filename
        self.error_message = str(error_messasge)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"Exception occurred in file: {self.filename} at line: {self.lineno} with error message: {self.error_message}\nTraceback:\n{self.traceback_str}"

if __name__ == "__main__":
    try:
        a = 1 / 0
        print(a)
    except Exception as e:
        logger.error(f"An error occurred: {e}")
        raise DocumentPortalException(e, sys)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 19
#      17     except Exception as e:
#      18         logger.error(f"An error occurred: {e}")
# ---> 19         raise DocumentPortalException(e, sys)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[10], line 19
#      15         a = 1 / 0
#      16         print(a)
#      17     except Exception as e:
#      18         logger.error(f"An error occurred: {e}")
# ---> 19         raise DocumentPortalException(e, sys)
#
# DocumentPortalException: Exception occurred in file: C:\Users\mkuma\AppData\Local\Temp\ipykernel_17180\121141151.py at line: 15 with error message: division by zero
# Traceback:
# Traceback (most recent call last):
# ...
